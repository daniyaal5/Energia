# %%
import pandas as pd
import numpy as np
import glob 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ## Excel Files Concatenation

# %%
# Path for all the weekly excel files for the month of March
path = "C:/Users/daniy/Desktop/Energia"
joined_files = os.path.join(path, "March*.csv") 
  
# A list of all joined files is returned 
joined_list = glob.glob(joined_files) 

energia_data = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Using the copy of energia_data to perform exploratory data analysis so that the original dataframe does not get changed
energia_data_copy = energia_data.copy()
energia_data_copy.shape

# %%
energia_data_copy.head()
# Out:
#    AnonymisedMPRN                             Tariff  \
# 0     10064959502  SMTOU0006 - Smart 24 hour Replica
# 1     10064959502  SMTOU0006 - Smart 24 hour Replica
# 2     10064959502  SMTOU0006 - Smart 24 hour Replica
# 3     10064959502  SMTOU0006 - Smart 24 hour Replica
# 4     10064959502  SMTOU0006 - Smart 24 hour Replica
#
#                           Product Name  Product Code              ReadingDate  \
# 0  DF RET 12 Mth Mcc12 TOU 24 hour 10%          1743  2024-03-01 00:00:00.000
# 1  DF RET 12 Mth Mcc12 TOU 24 hour 10%          1743  2024-03-02 00:00:00.000
# 2  DF RET 12 Mth Mcc12 TOU 24 hour 10%          1743  2024-03-03 00:00:00.000
# 3  DF RET 12 Mth Mcc12 TOU 24 hour 10%          1743  2024-03-04 00:00:00.000
# 4  DF RET 12 Mth Mcc12 TOU 24 hour 10%          1743  2024-03-05 00:00:00.000
#
#    00:00:00  00:30:00  01:00:00  01:30:00  02:00:00  ...  19:00:00  19:30:00  \
# 0     0.051     0.050     0.054     0.050     0.064  ...     0.266     0.282
# 1     0.051     0.055     0.061     0.037     0.064  ...     0.218     0.399
# 2     0.052     0.087     0.092     0.054     0.060  ...     0.080     0.310
# 3     0.058     0.069     0.046     0.093     0.074  ...     0.598     0.289
# 4     0.056     0.052     0.052     0.059     0.035  ...     0.661     0.412
#
#    20:00:00  20:30:00  21:00:00  21:30:00  22:00:00  22:30:00  23:00:00  \
# 0     0.560     0.305     0.294     0.265     0.222     0.209     0.193
# 1     0.405     0.603     0.937     0.446     0.565     0.264     0.705
# 2     0.552     0.299     0.313     0.250     0.165     0.144     0.161
# 3     0.465     0.461     0.196     0.295     0.144     0.181     0.187
# 4     0.209     0.696     0.165     0.178     0.234     0.238     0.092
#
#    23:30:00
# 0     0.088
# 1     0.083
# 2     0.110
# 3     0.119
# 4     0.222
#
# [5 rows x 53 columns]

# %%
energia_data_copy.describe()
# Out:
#        AnonymisedMPRN  Product Code      00:00:00      00:30:00      01:00:00  \
# count    1.303002e+06  1.303002e+06  1.303002e+06  1.303002e+06  1.259309e+06
# mean     1.013317e+10  1.725598e+03  2.792959e-01  2.588643e-01  2.494834e-01
# std      1.127303e+08  1.892523e+02  5.547462e-01  5.436710e-01  5.455054e-01
# min      1.003935e+10  2.540000e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      1.005378e+10  1.716000e+03  5.700000e-02  5.200000e-02  4.900000e-02
# 50%      1.006119e+10  1.742000e+03  1.080000e-01  9.650000e-02  8.900000e-02
# 75%      1.029434e+10  1.796000e+03  2.350000e-01  2.050000e-01  1.845000e-01
# max      1.030331e+10  2.347000e+03  9.998000e+00  1.007600e+01  9.847000e+00
#
#            01:30:00      02:00:00      02:30:00      03:00:00      03:30:00  \
# count  1.259309e+06  1.303002e+06  1.303002e+06  1.303002e+06  1.303002e+06
# mean   2.371803e-01  3.616307e-01  3.578395e-01  3.476551e-01  3.225936e-01
# std    5.291995e-01  8.204206e-01  8.355566e-01  8.159219e-01  7.655747e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.750000e-02  4.800000e-02  4.600000e-02  4.500000e-02  4.400000e-02
# 50%    8.450000e-02  8.500000e-02  8.200000e-02  7.950000e-02  7.800000e-02
# 75%    1.730000e-01  1.955000e-01  1.845000e-01  1.775000e-01  1.710000e-01
# max    9.888000e+00  1.018500e+01  1.118700e+01  1.108200e+01  1.006000e+01
#
#        ...      19:00:00      19:30:00      20:00:00      20:30:00  \
# count  ...  1.303002e+06  1.303002e+06  1.303002e+06  1.303002e+06
# mean   ...  4.307947e-01  4.245525e-01  4.114565e-01  3.957454e-01
# std    ...  5.155615e-01  5.128998e-01  5.028467e-01  4.903306e-01
# min    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  1.155000e-01  1.195000e-01  1.205000e-01  1.200000e-01
# 50%    ...  2.500000e-01  2.480000e-01  2.415000e-01  2.330000e-01
# 75%    ...  5.625000e-01  5.395000e-01  5.090000e-01  4.770000e-01
# max    ...  8.793500e+00  8.671000e+00  8.822500e+00  8.464000e+00
#
#            21:00:00      21:30:00      22:00:00      22:30:00      23:00:00  \
# count  1.303002e+06  1.303002e+06  1.303002e+06  1.303002e+06  1.303002e+06
# mean   3.775489e-01  3.545402e-01  3.289338e-01  3.011974e-01  3.069201e-01
# std    4.754490e-01  4.601974e-01  4.466429e-01  4.342162e-01  5.158745e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.160000e-01  1.090000e-01  9.800000e-02  8.500000e-02  7.300000e-02
# 50%    2.230000e-01  2.075000e-01  1.890000e-01  1.670000e-01  1.460000e-01
# 75%    4.455000e-01  4.090000e-01  3.705000e-01  3.300000e-01  3.060000e-01
# max    8.015000e+00  8.105000e+00  7.623000e+00  7.503000e+00  8.986000e+00
#
#            23:30:00
# count  1.303002e+06
# mean   2.889410e-01
# std    5.321722e-01
# min    0.000000e+00
# 25%    6.350000e-02
# 50%    1.250000e-01
# 75%    2.690000e-01
# max    9.949000e+00
#
# [8 rows x 50 columns]

# %%
energia_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303002 entries, 0 to 1303001
# Data columns (total 53 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   AnonymisedMPRN  1303002 non-null  int64
#  1   Tariff          1303002 non-null  object
#  2   Product Name    1303002 non-null  object
#  3   Product Code    1303002 non-null  int64
#  4   ReadingDate     1303002 non-null  object
#  5   00:00:00        1303002 non-null  float64
#  6   00:30:00        1303002 non-null  float64
#  7   01:00:00        1259309 non-null  float64
#  8   01:30:00        1259309 non-null  float64
#  9   02:00:00        1303002 non-null  float64
#  10  02:30:00        1303002 non-null  float64
#  11  03:00:00        1303002 non-null  float64
#  12  03:30:00        1303002 non-null  float64
#  13  04:00:00        1303002 non-null  float64
#  14  04:30:00        1303002 non-null  float64
#  15  05:00:00        1303002 non-null  float64
#  16  05:30:00        1303002 non-null  float64
#  17  06:00:00        1303002 non-null  float64
#  18  06:30:00        1303002 non-null  float64
#  19  07:00:00        1303002 non-null  float64
#  20  07:30:00        1303002 non-null  float64
#  21  08:00:00        1303002 non-null  float64
#  22  08:30:00        1303002 non-null  float64
#  23  09:00:00        1303002 non-null  float64
#  24  09:30:00        1303002 non-null  float64
#  25  10:00:00        1303002 non-null  float64
#  26  10:30:00        1303002 non-null  float64
#  27  11:00:00        1303002 non-null  float64
#  28  11:30:00        1303002 non-null  float64
#  29  12:00:00        1303002 non-null  float64
#  30  12:30:00        1303002 non-null  float64
#  31  13:00:00        1303002 non-null  float64
#  32  13:30:00        1303002 non-null  float64
#  33  14:00:00        1303002 non-null  float64
#  34  14:30:00        1303002 non-null  float64
#  35  15:00:00        1303002 non-null  float64
#  36  15:30:00        1303002 non-null  float64
#  37  16:00:00        1303002 non-null  float64
#  38  16:30:00        1303002 non-null  float64
#  39  17:00:00        1303002 non-null  float64
#  40  17:30:00        1303002 non-null  float64
#  41  18:00:00        1303002 non-null  float64
#  42  18:30:00        1303002 non-null  float64
#  43  19:00:00        1303002 non-null  float64
#  44  19:30:00        1303002 non-null  float64
#  45  20:00:00        1303002 non-null  float64
#  46  20:30:00        1303002 non-null  float64
#  47  21:00:00        1303002 non-null  float64
#  48  21:30:00        1303002 non-null  float64
#  49  22:00:00        1303002 non-null  float64
#  50  22:30:00        1303002 non-null  float64
#  51  23:00:00        1303002 non-null  float64
#  52  23:30:00        1303002 non-null  float64
# dtypes: float64(48), int64(2), object(3)
# memory usage: 526.9+ MB

# %%
energia_data_copy.nunique()
# Out:
# AnonymisedMPRN    43699
# Tariff                8
# Product Name        282
# Product Code        282
# ReadingDate          31
# 00:00:00           9838
# 00:30:00           9721
# 01:00:00           9698
# 01:30:00           9478
# 02:00:00          12233
# 02:30:00          12455
# 03:00:00          12277
# 03:30:00          11781
# 04:00:00          11560
# 04:30:00          11117
# 05:00:00          10603
# 05:30:00           9875
# 06:00:00           8411
# 06:30:00           8412
# 07:00:00           8411
# 07:30:00           8347
# 08:00:00           8008
# 08:30:00           7934
# 09:00:00           7948
# 09:30:00           7926
# 10:00:00           7824
# 10:30:00           7773
# 11:00:00           7799
# 11:30:00           7762
# 12:00:00           7741
# 12:30:00           7721
# 13:00:00           7775
# 13:30:00           7684
# 14:00:00           7631
# 14:30:00           7586
# 15:00:00           7639
# 15:30:00           7744
# 16:00:00           7979
# 16:30:00           8176
# 17:00:00           8519
# 17:30:00           8695
# 18:00:00           8899
# 18:30:00           8967
# 19:00:00           9094
# 19:30:00           9215
# 20:00:00           9156
# 20:30:00           9064
# 21:00:00           8975
# 21:30:00           8890
# 22:00:00           8800
# 22:30:00           8654
# 23:00:00           9500
# 23:30:00           9653
# dtype: int64

# %%
energia_data_copy.columns
# Out:
# Index(['AnonymisedMPRN', 'Tariff', 'Product Name', 'Product Code',
#        'ReadingDate', '00:00:00', '00:30:00', '01:00:00', '01:30:00',
#        '02:00:00', '02:30:00', '03:00:00', '03:30:00', '04:00:00', '04:30:00',
#        '05:00:00', '05:30:00', '06:00:00', '06:30:00', '07:00:00', '07:30:00',
#        '08:00:00', '08:30:00', '09:00:00', '09:30:00', '10:00:00', '10:30:00',
#        '11:00:00', '11:30:00', '12:00:00', '12:30:00', '13:00:00', '13:30:00',
#        '14:00:00', '14:30:00', '15:00:00', '15:30:00', '16:00:00', '16:30:00',
#        '17:00:00', '17:30:00', '18:00:00', '18:30:00', '19:00:00', '19:30:00',
#        '20:00:00', '20:30:00', '21:00:00', '21:30:00', '22:00:00', '22:30:00',
#        '23:00:00', '23:30:00'],
#       dtype='object')

# %%
data_measures = energia_data_copy.describe()

# %% [markdown]
# # Mean of Each Time Interval

# %%
plt.bar(data_measures.columns[2:], data_measures.iloc[1, 2:], color='skyblue')

# Rotate the x labels
plt.xticks(rotation=90)
plt.title('Mean of Electricity Consumption for Each Time Interval')
plt.xlabel('Time Interval')
plt.ylabel('Consumption')
plt.tight_layout()
plt.show()

# %%
plt.plot(data_measures.iloc[1, 2:], label = "Mean")
plt.plot(data_measures.iloc[3, 2:], label = "Min")
plt.plot(data_measures.iloc[-1, 2:], label = "Max")
plt.xticks(rotation=90)
plt.title('Mean, Min, and Max of Electricity Consumption for Each Time Interval')
plt.xlabel('Time Interval')
plt.ylabel('Consumption')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Weekdays and Weekends

# %%
# Convert the ReadingDate column from object to datetime64
energia_data_copy['ReadingDate'] = pd.to_datetime(energia_data_copy['ReadingDate'])
energia_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303002 entries, 0 to 1303001
# Data columns (total 53 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   AnonymisedMPRN  1303002 non-null  int64
#  1   Tariff          1303002 non-null  object
#  2   Product Name    1303002 non-null  object
#  3   Product Code    1303002 non-null  int64
#  4   ReadingDate     1303002 non-null  datetime64[ns]
#  5   00:00:00        1303002 non-null  float64
#  6   00:30:00        1303002 non-null  float64
#  7   01:00:00        1259309 non-null  float64
#  8   01:30:00        1259309 non-null  float64
#  9   02:00:00        1303002 non-null  float64
#  10  02:30:00        1303002 non-null  float64
#  11  03:00:00        1303002 non-null  float64
#  12  03:30:00        1303002 non-null  float64
#  13  04:00:00        1303002 non-null  float64
#  14  04:30:00        1303002 non-null  float64
#  15  05:00:00        1303002 non-null  float64
#  16  05:30:00        1303002 non-null  float64
#  17  06:00:00        1303002 non-null  float64
#  18  06:30:00        1303002 non-null  float64
#  19  07:00:00        1303002 non-null  float64
#  20  07:30:00        1303002 non-null  float64
#  21  08:00:00        1303002 non-null  float64
#  22  08:30:00        1303002 non-null  float64
#  23  09:00:00        1303002 non-null  float64
#  24  09:30:00        1303002 non-null  float64
#  25  10:00:00        1303002 non-null  float64
#  26  10:30:00        1303002 non-null  float64
#  27  11:00:00        1303002 non-null  float64
#  28  11:30:00        1303002 non-null  float64
#  29  12:00:00        1303002 non-null  float64
#  30  12:30:00        1303002 non-null  float64
#  31  13:00:00        1303002 non-null  float64
#  32  13:30:00        1303002 non-null  float64
#  33  14:00:00        1303002 non-null  float64
#  34  14:30:00        1303002 non-null  float64
#  35  15:00:00        1303002 non-null  float64
#  36  15:30:00        1303002 non-null  float64
#  37  16:00:00        1303002 non-null  float64
#  38  16:30:00        1303002 non-null  float64
#  39  17:00:00        1303002 non-null  float64
#  40  17:30:00        1303002 non-null  float64
#  41  18:00:00        1303002 non-null  float64
#  42  18:30:00        1303002 non-null  float64
#  43  19:00:00        1303002 non-null  float64
#  44  19:30:00        1303002 non-null  float64
#  45  20:00:00        1303002 non-null  float64
#  46  20:30:00        1303002 non-null  float64
#  47  21:00:00        1303002 non-null  float64
#  48  21:30:00        1303002 non-null  float64
#  49  22:00:00        1303002 non-null  float64
#  50  22:30:00        1303002 non-null  float64
#  51  23:00:00        1303002 non-null  float64
#  52  23:30:00        1303002 non-null  float64
# dtypes: datetime64[ns](1), float64(48), int64(2), object(2)
# memory usage: 526.9+ MB

# %%
energia_data_copy['DayOfWeek'] = energia_data_copy['ReadingDate'].dt.dayofweek
energia_data_copy.iloc[:, 5:]

# %%
weekend_data = energia_data_copy[(energia_data_copy['DayOfWeek'] == 5) | (energia_data_copy['DayOfWeek'] == 6)]
weekend_data.shape
# Out:
# (419917, 54)

# %%
weekend_data.describe()
# Out:
#        AnonymisedMPRN   Product Code       00:00:00       00:30:00  \
# count    4.199170e+05  419917.000000  419917.000000  419917.000000
# mean     1.013317e+10    1725.409386       0.294036       0.274026
# std      1.127320e+08     189.106563       0.556439       0.548473
# min      1.003935e+10     254.000000       0.000000       0.000000
# 25%      1.005378e+10    1716.000000       0.060500       0.055000
# 50%      1.006119e+10    1742.000000       0.119500       0.105000
# 75%      1.029434e+10    1796.000000       0.261000       0.229000
# max      1.030331e+10    2347.000000       9.998000      10.076000
#
#             01:00:00       01:30:00       02:00:00       02:30:00  \
# count  376224.000000  376224.000000  419917.000000  419917.000000
# mean        0.266538       0.252371       0.367297       0.363404
# std         0.557220       0.540991       0.814136       0.830361
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.052000       0.049500       0.049000       0.047500
# 50%         0.096000       0.090000       0.090000       0.085000
# 75%         0.208000       0.191500       0.214000       0.200000
# max         9.847000       9.888000      10.185000      11.187000
#
#             03:00:00       03:30:00  ...       19:30:00       20:00:00  \
# count  419917.000000  419917.000000  ...  419917.000000  419917.000000
# mean        0.354751       0.331000  ...       0.408935       0.393825
# std         0.817622       0.771893  ...       0.503987       0.488703
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.046000       0.045000  ...       0.110000       0.112000
# 50%         0.082000       0.080000  ...       0.235500       0.230000
# 75%         0.189500       0.181000  ...       0.517500       0.485000
# max        11.082000      10.060000  ...       8.671000       8.425500
#
#             20:30:00       21:00:00       21:30:00       22:00:00  \
# count  419917.000000  419917.000000  419917.000000  419917.000000
# mean        0.376868       0.358554       0.337969       0.316015
# std         0.471978       0.453453       0.437226       0.424506
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.112000       0.109500       0.104000       0.095500
# 50%         0.222500       0.213500       0.201000       0.185500
# 75%         0.452000       0.422500       0.390500       0.358000
# max         8.464000       7.108000       8.105000       7.442500
#
#             22:30:00       23:00:00       23:30:00      DayOfWeek
# count  419917.000000  419917.000000  419917.000000  419917.000000
# mean        0.294046       0.300152       0.285215       5.500001
# std         0.415033       0.491565       0.509760       0.500001
# min         0.000000       0.000000       0.000000       5.000000
# 25%         0.085000       0.074500       0.065000       5.000000
# 50%         0.168000       0.150000       0.130000       6.000000
# 75%         0.326000       0.307000       0.275500       6.000000
# max         6.961500       8.986000       9.949000       6.000000
#
# [8 rows x 51 columns]

# %%
weekday_data = energia_data_copy[(energia_data_copy['DayOfWeek'] != 5) & (energia_data_copy['DayOfWeek'] != 6)]
weekday_data.shape
# Out:
# (883085, 54)

# %%
weekday_data.describe()
# Out:
#        AnonymisedMPRN   Product Code       00:00:00       00:30:00  \
# count    8.830850e+05  883085.000000  883085.000000  883085.000000
# mean     1.013317e+10    1725.686962       0.272287       0.251655
# std      1.127296e+08     189.321594       0.553802       0.541224
# min      1.003935e+10     254.000000       0.000000       0.000000
# 25%      1.005378e+10    1716.000000       0.055500       0.051000
# 50%      1.006119e+10    1742.000000       0.103500       0.092500
# 75%      1.029433e+10    1796.000000       0.223000       0.193500
# max      1.030331e+10    2347.000000       8.255000       8.285000
#
#             01:00:00       01:30:00       02:00:00       02:30:00  \
# count  883085.000000  883085.000000  883085.000000  883085.000000
# mean        0.242217       0.230708       0.358936       0.355194
# std         0.540274       0.523962       0.823379       0.838003
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.048000       0.047000       0.047000       0.045500
# 50%         0.086000       0.082500       0.083000       0.080000
# 75%         0.175000       0.165000       0.187000       0.178000
# max         8.250000       8.223000       9.007000       9.518000
#
#             03:00:00       03:30:00  ...       19:30:00       20:00:00  \
# count  883085.000000  883085.000000  ...  883085.000000  883085.000000
# mean        0.344281       0.318596  ...       0.431979       0.419841
# std         0.815091       0.762520  ...       0.516919       0.509220
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.044500       0.044000  ...       0.124000       0.125000
# 50%         0.078000       0.077000  ...       0.254000       0.247500
# 75%         0.172000       0.166000  ...       0.550500       0.520500
# max         9.556000       9.495000  ...       8.539000       8.822500
#
#             20:30:00       21:00:00       21:30:00       22:00:00  \
# count  883085.000000  883085.000000  883085.000000  883085.000000
# mean        0.404722       0.386581       0.362420       0.335077
# std         0.498570       0.485299       0.470523       0.456665
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.123500       0.119500       0.111000       0.099500
# 50%         0.238000       0.227000       0.211000       0.191000
# 75%         0.489000       0.457000       0.417500       0.376500
# max         8.413500       8.015000       7.262500       7.623000
#
#             22:30:00       23:00:00       23:30:00      DayOfWeek
# count  883085.000000  883085.000000  883085.000000  883085.000000
# mean        0.304598       0.310138       0.290713       2.098701
# std         0.443006       0.527010       0.542496       1.442243
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.085000       0.072500       0.062500       1.000000
# 50%         0.167000       0.144500       0.122500       2.000000
# 75%         0.332000       0.305500       0.265500       3.000000
# max         7.503000       7.839500       8.040000       4.000000
#
# [8 rows x 51 columns]

# %%
plt.bar(weekend_data.describe().columns[2:-1], weekend_data.describe().iloc[1, 2:-1], color='skyblue', label = "Weekends")
plt.bar(weekday_data.describe().columns[2:-1], weekday_data.describe().iloc[1, 2:-1], color='orange', alpha = 0.7, label = "Weekdays")

# Rotate the x labels
plt.xticks(rotation=90)
plt.title('Mean of Electricity Consumption on Weekends and Weekdays')
plt.xlabel('Time Interval')
plt.ylabel('Consumption')
plt.tight_layout()
plt.legend()
plt.show()

# %%
plt.plot(weekday_data.describe().iloc[1, 2:-1], label = "Mean on Weekdays")
plt.plot(weekday_data.describe().iloc[3, 2:-1], label = "Min on Weekdays")
plt.plot(weekday_data.describe().iloc[-1, 2:-1], label = "Max on Weekdays")
plt.plot(weekend_data.describe().iloc[1, 2:-1], label = "Mean on Weekends")
plt.plot(weekend_data.describe().iloc[3, 2:-1], label = "Min on Weekends")
plt.plot(weekend_data.describe().iloc[-1, 2:-1], label = "Max on Weekends")
plt.xticks(rotation=90)
plt.title('Mean, Min, and Max of Electricity Consumption on Weekdays and Weekends for Each Time Interval')
plt.xlabel('Time Interval')
plt.ylabel('Consumption')
plt.legend()
plt.tight_layout()
plt.show()

# %%
for i in energia_data_copy.columns[5:]:
    plt.boxplot(energia_data_copy.iloc[:, 5:-1][i])
    plt.title(i)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DayOfWeek'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 for i in energia_data_copy.columns[5:]:
# ----> 2     plt.boxplot(energia_data[i])
#       3     plt.title(i)
#       4     plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'DayOfWeek'

# %%
time_interval_columns = energia_data_copy.columns[5:-1]
time_interval_columns
# Out:
# Index(['00:00:00', '00:30:00', '01:00:00', '01:30:00', '02:00:00', '02:30:00',
#        '03:00:00', '03:30:00', '04:00:00', '04:30:00', '05:00:00', '05:30:00',
#        '06:00:00', '06:30:00', '07:00:00', '07:30:00', '08:00:00', '08:30:00',
#        '09:00:00', '09:30:00', '10:00:00', '10:30:00', '11:00:00', '11:30:00',
#        '12:00:00', '12:30:00', '13:00:00', '13:30:00', '14:00:00', '14:30:00',
#        '15:00:00', '15:30:00', '16:00:00', '16:30:00', '17:00:00', '17:30:00',
#        '18:00:00', '18:30:00', '19:00:00', '19:30:00', '20:00:00', '20:30:00',
#        '21:00:00', '21:30:00', '22:00:00', '22:30:00', '23:00:00', '23:30:00'],
#       dtype='object')

# %%
# Visualizing with histograms
for col in time_interval_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(energia_data_copy.iloc[:, 5:-1][col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# Visualizing with Q-Q plots
for col in time_interval_columns:
    plt.figure(figsize=(6, 6))
    stats.probplot(energia_data_copy.iloc[:, 5:-1][col], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {col}')
    plt.show()

# %%
energia_data_copy.groupby("Product Code").mean().iloc[:, 1:]
# Out:
# C:\Users\daniy\AppData\Local\Temp\ipykernel_11632\3664485246.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   energia_data_copy.groupby("Product Code").mean().iloc[:, 1:]
#               00:00:00  00:30:00  01:00:00  01:30:00  02:00:00  02:30:00  \
# Product Code
# 254           0.259835  0.231170  0.212044  0.175000  0.181152  0.161539
# 255           0.308413  0.302955  0.247753  0.197180  0.161111  0.182769
# 260           0.170977  0.159089  0.148574  0.137374  0.135568  0.127869
# 261           0.233780  0.240185  0.231033  0.213479  0.186619  0.172450
# 262           0.159367  0.153213  0.141841  0.126993  0.112156  0.099953
# ...                ...       ...       ...       ...       ...       ...
# 2330          0.228403  0.216543  0.204587  0.209475  0.222513  0.201017
# 2331          0.167168  0.148336  0.122653  0.099547  0.124530  0.149844
# 2333          0.168059  0.151016  0.149031  0.141438  0.138566  0.129786
# 2334          0.119422  0.102961  0.090143  0.084141  0.076838  0.073015
# 2347          0.127935  0.093129  0.082733  0.079883  0.075387  0.084242
#
#               03:00:00  03:30:00  04:00:00  04:30:00  ...  19:30:00  20:00:00  \
# Product Code                                          ...
# 254           0.156724  0.150486  0.148075  0.146500  ...  0.452392  0.457812
# 255           0.109921  0.092992  0.091174  0.092384  ...  0.367077  0.426819
# 260           0.120089  0.112953  0.106661  0.101686  ...  0.289424  0.284869
# 261           0.179275  0.183020  0.163259  0.145578  ...  0.406216  0.397959
# 262           0.092968  0.090685  0.098360  0.107097  ...  0.296991  0.294434
# ...                ...       ...       ...       ...  ...       ...       ...
# 2330          0.196885  0.191733  0.201505  0.172688  ...  0.358977  0.361313
# 2331          0.176966  0.170743  0.147085  0.126331  ...  0.280902  0.253051
# 2333          0.123352  0.122357  0.121509  0.127927  ...  0.342719  0.333248
# 2334          0.073608  0.068484  0.081354  0.067520  ...  0.244438  0.244460
# 2347          0.081129  0.080484  0.085694  0.088952  ...  0.215145  0.192597
#
#               20:30:00  21:00:00  21:30:00  22:00:00  22:30:00  23:00:00  \
# Product Code
# 254           0.461050  0.410505  0.455590  0.409853  0.402394  0.377457
# 255           0.429708  0.385626  0.458287  0.409485  0.358073  0.355968
# 260           0.273315  0.242427  0.236926  0.222986  0.207483  0.227376
# 261           0.380722  0.350127  0.315574  0.271714  0.260403  0.257059
# 262           0.255765  0.254299  0.226866  0.215242  0.239867  0.179219
# ...                ...       ...       ...       ...       ...       ...
# 2330          0.360048  0.361676  0.351229  0.329381  0.294059  0.272695
# 2331          0.248907  0.237832  0.219362  0.200499  0.179006  0.208354
# 2333          0.330460  0.297366  0.254804  0.237349  0.213042  0.195241
# 2334          0.252675  0.246134  0.224198  0.217055  0.209932  0.193932
# 2347          0.228468  0.210274  0.262210  0.248806  0.198500  0.185581
#
#               23:30:00  DayOfWeek
# Product Code
# 254           0.289697   3.193548
# 255           0.261408   3.193548
# 260           0.209557   3.193548
# 261           0.238508   3.193548
# 262           0.170692   3.193548
# ...                ...        ...
# 2330          0.245896   3.207438
# 2331          0.193421   3.193392
# 2333          0.183412   3.196850
# 2334          0.148967   3.191142
# 2347          0.149855   3.193548
#
# [282 rows x 49 columns]

# %% [markdown]
# ### Exporting the merged data for March 2024.

# %%
energia_data.to_csv("March2024.csv", index = False)
